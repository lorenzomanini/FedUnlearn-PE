# %%
import os
import pickle

import numpy as np
from matplotlib import pyplot as plt

# %%
stat_test_name = "Breast_Cancer_Unlearning_Information_Method (1)"

stat_tests_path = "stat_tests/CHECK ONLY" 
LOAD_2 = True

stat_test_path = os.path.join(stat_tests_path, stat_test_name)
if not os.path.exists(stat_test_path):
    raise FileNotFoundError(f"Stat test path {stat_test_path} does not exist.")

init_params_path = os.path.join(stat_test_path, "init_params.pkl")
test_params_path = os.path.join(stat_test_path, "test_params.pkl")

with open(init_params_path, "rb") as f:
    init_params = pickle.load(f)
with open(test_params_path, "rb") as f:
    test_params = pickle.load(f)


print("Init params:")
for k, v in init_params.items():
    print(f"{k}: {v}")

num_tests = init_params["num_tests"]


distribution_type = init_params["distribution_type"]

tests_results = []  # 2-dim list [idx of repeated test][idx of test]
for i in range(num_tests):
    test_path = os.path.join(stat_test_path, f"test_{i}")
    test_result_path = os.path.join(test_path, "test_results.pkl")
    
    with open(test_result_path, "rb") as f:
        test_result = pickle.load(f)
        
    tests_results.append(test_result)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[23], line 8
#       6 stat_test_path = os.path.join(stat_tests_path, stat_test_name)
#       7 if not os.path.exists(stat_test_path):
# ----> 8     raise FileNotFoundError(f"Stat test path {stat_test_path} does not exist.")
#      10 init_params_path = os.path.join(stat_test_path, "init_params.pkl")
#      11 test_params_path = os.path.join(stat_test_path, "test_params.pkl")
#
# FileNotFoundError: Stat test path stat_tests/CHECK ONLY\Breast_Cancer_Unlearning_Information_Method (1) does not exist.

# %%
if LOAD_2:
    stat_tests_path = "stat_tests/MC2" 
    stat_test_path = os.path.join(stat_tests_path, stat_test_name)
    if not os.path.exists(stat_test_path):
        raise FileNotFoundError(f"Stat test path {stat_test_path} does not exist.")

    with open(init_params_path, "rb") as f:
        init_params = pickle.load(f)
    with open(test_params_path, "rb") as f:
        test_params = pickle.load(f)


    print("Init params:")
    for k, v in init_params.items():
        print(f"{k}: {v}")

    num_tests2 = init_params["num_tests"]
    num_tests2 = 10 

    for i in range(num_tests2):
        test_path = os.path.join(stat_test_path, f"test_{i}")
        test_result_path = os.path.join(test_path, "test_results.pkl")
        
        with open(test_result_path, "rb") as f:
            test_result = pickle.load(f)
            
        tests_results.append(test_result)

    num_tests += num_tests2
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[15], line 5
#       3 stat_test_path = os.path.join(stat_tests_path, stat_test_name)
#       4 if not os.path.exists(stat_test_path):
# ----> 5     raise FileNotFoundError(f"Stat test path {stat_test_path} does not exist.")
#       7 with open(init_params_path, "rb") as f:
#       8     init_params = pickle.load(f)
#
# FileNotFoundError: Stat test path stat_tests/MC2\Breast_Cancer_Unlearning_Information_Method (1) does not exist.

# %%
if distribution_type == "random" or distribution_type == "dirichlet":
    for i in range(num_tests):
        for j in range(len(tests_results[i])):
            tests_results[i][j]['trained_target_accuracy'] = tests_results[i][j]['trained_clients_accuracies'][init_params['target_client']]
            tests_results[i][j]['benchmark_target_accuracy'] = tests_results[i][j]['benchmark_clients_accuracies'][init_params['target_client']]
            tests_results[i][j]['reset_target_accuracy'] = tests_results[i][j]['reset_clients_accuracies'][init_params['target_client']]
            tests_results[i][j]['retrained_target_accuracy'] = tests_results[i][j]['retrained_clients_accuracies'][init_params['target_client']]
            tests_results[i][j]['random_reset_target_accuracy'] = tests_results[i][j]['random_reset_clients_accuracies'][init_params['target_client']]
            tests_results[i][j]['random_retrained_target_accuracy'] = tests_results[i][j]['random_retrained_clients_accuracies'][init_params['target_client']]
if distribution_type == "preferential_class":
    for i in range(num_tests):
        for j in range(len(tests_results[i])):
            tests_results[i][j]['trained_target_accuracy'] = tests_results[i][j]['trained_class_accuracies'][init_params['target_client']+init_params['num_clients']]
            tests_results[i][j]['benchmark_target_accuracy'] = tests_results[i][j]['benchmark_class_accuracies'][init_params['target_client']+init_params['num_clients']]
            tests_results[i][j]['reset_target_accuracy'] = tests_results[i][j]['reset_class_accuracies'][init_params['target_client']+init_params['num_clients']]
            tests_results[i][j]['retrained_target_accuracy'] = tests_results[i][j]['retrained_class_accuracies'][init_params['target_client']+init_params['num_clients']]
            tests_results[i][j]['random_reset_target_accuracy'] = tests_results[i][j]['random_reset_class_accuracies'][init_params['target_client']+init_params['num_clients']]
            tests_results[i][j]['random_retrained_target_accuracy'] = tests_results[i][j]['random_retrained_class_accuracies'][init_params['target_client']+init_params['num_clients']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[5], line 4
#       2 for i in range(num_tests):
#       3     for j in range(len(tests_results[i])):
# ----> 4         tests_results[i][j]['trained_target_accuracy'] = tests_results[i][j]['trained_clients_accuracies'][init_params['target_client']]
#       5         tests_results[i][j]['benchmark_target_accuracy'] = tests_results[i][j]['benchmark_clients_accuracies'][init_params['target_client']]
#       6         tests_results[i][j]['reset_target_accuracy'] = tests_results[i][j]['reset_clients_accuracies'][init_params['target_client']]
#
# KeyError: 'trained_clients_accuracies'

# %% [markdown]
# for i in range(num_tests):
#         for j in range(len(tests_results[i])):
#             tests_results[i][j]['trained_target_accuracy'] = tests_results[i][j]['trained_clients_accuracies'][init_params['target_client']]
#             tests_results[i][j]['benchmark_target_accuracy'] = tests_results[i][j]['benchmark_clients_accuracies'][init_params['target_client']]
#             tests_results[i][j]['reset_target_accuracy'] = tests_results[i][j]['reset_clients_accuracies'][init_params['target_client']]
#             tests_results[i][j]['retrained_target_accuracy'] = tests_results[i][j]['retrained_clients_accuracies'][init_params['target_client']]
#             tests_results[i][j]['random_reset_target_accuracy'] = tests_results[i][j]['random_reset_clients_accuracies'][init_params['target_client']]
#             tests_results[i][j]['random_retrained_target_accuracy'] = tests_results[i][j]['random_retrained_clients_accuracies'][init_params['target_client']]

# %%
subtest = 0

subtest_params = []
subtest_results = []    # 2-dim list [idx of test][idx of repeated test]
for i, test_param in enumerate(test_params):
    if test_param["subtest"] == subtest:
        subtest_params.append(test_param)
        subtest_results.append([])
        for j in range(num_tests):
            subtest_results[-1].append(tests_results[j][i])

n=None
if n is not None:
    subtest_params = subtest_params[:n]
    subtest_results = subtest_results[:n]

print("Subtest params:")
for key, value_key in subtest_params[0].items():
    if key == "unlearning_percentage":
        continue
    print(f"{key}: {value_key}")

print(f"\nAvailable results:")
for key in subtest_results[0][0].keys():
    print(key)

unlearning_percentages = []
for test_param in subtest_params:
    unlearning_percentages.append(int(test_param["unlearning_percentage"]))

print(f"\nUnlearning percentages: {unlearning_percentages}")
# Out:
# Subtest params:
# tests: ['test_accuracy']
# retrain_epochs: 1
# subtest: 0
# unlearning_method: information
#
# Available results:
# num_total_params
# num_reset_params
# reset_params_percentage
# trained_test_accuracy
# benchmark_test_accuracy
# reset_test_accuracy
# retrained_test_accuracy
# random_reset_test_accuracy
# random_retrained_test_accuracy
#
# Unlearning percentages: [0, 5]

# %%
# Compute avg number of reset parameters percentage
avg_reset_parameters = [np.mean([test_result['reset_params_percentage'] for test_result in subtest_result]) for subtest_result in subtest_results]
plt.scatter(unlearning_percentages, avg_reset_parameters)
plt.xlabel("Percentage of information reset")
plt.ylabel("Avg percentage of parameters reset")
# Out:
# Text(0, 0.5, 'Avg percentage of parameters reset')

# %%
def compute_NTA(model_key, benchmark_key='benchmark_test_accuracy'):
    benchmark_acc = [res[benchmark_key] for res in subtest_results[0]] # [idx of repeated test]
    model_acc = [[res[model_key] for res in results] for results in subtest_results] # [idx of test][idx of repeated test]
    print(f"Benchmark acc: {benchmark_acc}")
    print(f"Model acc: {model_acc}")
    nta_avg = [] # [idx of test]
    nta_std = [] # [idx of test]
    for test_acc in model_acc:
        nta_values = []
        for i in range(len(test_acc)):
            if benchmark_acc[i] == 0:
                nta_values.append(0)
            else:
                nta_values.append(test_acc[i] / benchmark_acc[i])
        nta_avg.append(np.mean(nta_values))
        nta_std.append(np.std(nta_values))
    return nta_avg, nta_std

# %%
# Compute NTA (Normalized Test Accuracy)

compute_NTA('trained_test_accuracy')
reset_nta_avg, reset_nta_std = compute_NTA('reset_test_accuracy')
retrained_nta_avg, retrained_nta_std = compute_NTA('retrained_test_accuracy')
random_reset_nta_avg, random_reset_nta_std = compute_NTA('random_reset_test_accuracy')
random_retrained_nta_avg, random_retrained_nta_std = compute_NTA('random_retrained_test_accuracy')

plt.errorbar(avg_reset_parameters, reset_nta_avg, yerr=reset_nta_std, label='Reset NTA', marker='o', linestyle='None')
plt.errorbar(avg_reset_parameters, random_reset_nta_avg, yerr=random_reset_nta_std, label='Random Reset NTA', marker='o', linestyle='None')
plt.title("Reset NTA vs Random Reset NTA")
plt.xlabel("Avg reset parameters (%)")
plt.ylabel("NTA")
plt.legend()
plt.grid()
plt.show()

plt.errorbar(avg_reset_parameters, retrained_nta_avg, yerr=retrained_nta_std, label='Retrained NTA', marker='o', linestyle='None')
plt.errorbar(avg_reset_parameters, random_retrained_nta_avg, yerr=random_retrained_nta_std, label='Random Retrained NTA', marker='o', linestyle='None')
plt.title("Retrained NTA vs Random Retrained NTA")
plt.xlabel("Avg reset parameters (%)")
plt.ylabel("NTA")
plt.legend()
plt.grid()
plt.show()
# Out:
# Benchmark acc: [0.8504999368690664]
# Model acc: [[0.8508546725909536], [0.8508546725909536]]
# Benchmark acc: [0.8504999368690664]
# Model acc: [[0.8508546725909536], [0.8417938805081739]]
# Benchmark acc: [0.8504999368690664]
# Model acc: [[0.8508546725909536], [0.8484256347665058]]
# Benchmark acc: [0.8504999368690664]
# Model acc: [[0.8508546725909536], [0.8493335177157425]]
# Benchmark acc: [0.8504999368690664]
# Model acc: [[0.8508546725909536], [0.8498145153047421]]

# %%
def compute_NFS(model_key, benchmark_key='benchmark_target_accuracy', trained_key='trained_target_accuracy'):
    benchmark_acc = [res[benchmark_key] for res in subtest_results[0]] # [idx of repeated test]
    trained_acc = [res[trained_key] for res in subtest_results[0]] # [idx of repeated test]
    model_acc = [[res[model_key] for res in results] for results in subtest_results] # [idx of test][idx of repeated test]

    nfs_avg = [] # [idx of test]
    nfs_std = [] # [idx of test]
    for test_acc in model_acc:
        nfs_values = []
        for i in range(len(test_acc)):
            if benchmark_acc[i] == trained_acc[i]:
                nfs_values.append(0)
            else:
                nfs_values.append((test_acc[i] - trained_acc[i]) / (benchmark_acc[i] - trained_acc[i]))
        nfs_avg.append(np.mean(nfs_values))
        nfs_std.append(np.std(nfs_values))
    return nfs_avg, nfs_std

# %%
# Compute NFS (Normalized Forgetting Score)

reset_nfs_avg, reset_nfs_std = compute_NFS('reset_target_accuracy')
retrained_nfs_avg, retrained_nfs_std = compute_NFS('retrained_target_accuracy')
random_reset_nfs_avg, random_reset_nfs_std = compute_NFS('random_reset_target_accuracy')
random_retrained_nfs_avg, random_retrained_nfs_std = compute_NFS('random_retrained_target_accuracy')

plt.errorbar(avg_reset_parameters, reset_nfs_avg, yerr=reset_nfs_std, label='Reset NFS', marker='o', linestyle='None')
plt.errorbar(avg_reset_parameters, random_reset_nfs_avg, yerr=random_reset_nfs_std, label='Random Reset NFS', marker='o', linestyle='None')
plt.title("Reset NFS vs Random Reset NFS")
plt.xlabel("Avg reset parameters (%)")
plt.ylabel("NFS")
plt.legend()
plt.grid()
plt.show()


plt.errorbar(avg_reset_parameters, retrained_nfs_avg, yerr=retrained_nfs_std, label='Retrained NFS', marker='o', linestyle='None')
plt.errorbar(avg_reset_parameters, random_retrained_nfs_avg, yerr=random_retrained_nfs_std, label='Random Retrained NFS', marker='o', linestyle='None')
plt.title("Retrained NFS vs Random Retrained NFS")
plt.xlabel("Avg reset parameters (%)")
plt.ylabel("NFS")
plt.legend()
plt.grid()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[29], line 3
#       1 # Compute NFS (Normalized Forgetting Score)
# ----> 3 reset_nfs_avg, reset_nfs_std = compute_NFS('reset_target_accuracy')
#       4 retrained_nfs_avg, retrained_nfs_std = compute_NFS('retrained_target_accuracy')
#       5 random_reset_nfs_avg, random_reset_nfs_std = compute_NFS('random_reset_target_accuracy')
#
# Cell In[28], line 2, in compute_NFS(model_key, benchmark_key, trained_key)
#       1 def compute_NFS(model_key, benchmark_key='benchmark_target_accuracy', trained_key='trained_target_accuracy'):
# ----> 2     benchmark_acc = [res[benchmark_key] for res in subtest_results[0]] # [idx of repeated test]
#       3     trained_acc = [res[trained_key] for res in subtest_results[0]] # [idx of repeated test]
#       4     model_acc = [[res[model_key] for res in results] for results in subtest_results] # [idx of test][idx of repeated test]
#
# Cell In[28], line 2, in <listcomp>(.0)
#       1 def compute_NFS(model_key, benchmark_key='benchmark_target_accuracy', trained_key='trained_target_accuracy'):
# ----> 2     benchmark_acc = [res[benchmark_key] for res in subtest_results[0]] # [idx of repeated test]
#       3     trained_acc = [res[trained_key] for res in subtest_results[0]] # [idx of repeated test]
#       4     model_acc = [[res[model_key] for res in results] for results in subtest_results] # [idx of test][idx of repeated test]
#
# KeyError: 'benchmark_target_accuracy'

# %%
def compute_NFS_MIA(model_key, benchmark_key='benchmark_mia', trained_key='trained_mia', mia_type='nn', value_key='accuracy'):
    benchmark_acc = [res[benchmark_key + '_' + mia_type][value_key] for res in subtest_results[0]] # [idx of repeated test]
    trained_acc = [res[trained_key + '_' + mia_type][value_key] for res in subtest_results[0]] # [idx of repeated test]
    model_acc = [[res[model_key + '_' + mia_type][value_key] for res in results] for results in subtest_results] # [idx of test][idx of repeated test]
    print(np.mean(benchmark_acc))
    print(np.mean(trained_acc))
    nfs_mia_avg = [] # [idx of test]
    nfs_mia_std = [] # [idx of test]
    for test_acc in model_acc:
        nfs_mia_values = []
        for i in range(len(test_acc)):
            if benchmark_acc[i] == trained_acc[i]:
                nfs_mia_values.append(0)
            else:
                nfs_mia_values.append((test_acc[i] - trained_acc[i]) / (benchmark_acc[i] - trained_acc[i]))
        nfs_mia_avg.append(np.mean(nfs_mia_values))
        nfs_mia_std.append(np.std(nfs_mia_values))
    return nfs_mia_avg, nfs_mia_std

# %%
# Compute NFS_MIA
if distribution_type == "random" or distribution_type == "dirichlet":
    reset_nfs_mia_avg, reset_nfs_mia_std = compute_NFS_MIA('reset_mia')
    retrained_nfs_mia_avg, retrained_nfs_mia_std = compute_NFS_MIA('retrained_mia')
    random_reset_nfs_mia_avg, random_reset_nfs_mia_std = compute_NFS_MIA('random_reset_mia')
    random_retrained_nfs_mia_avg, random_retrained_nfs_mia_std = compute_NFS_MIA('random_retrained_mia')

    plt.errorbar(avg_reset_parameters, reset_nfs_mia_avg, yerr=reset_nfs_mia_std, label='Reset NFS_MIA', marker='o', linestyle='None')
    plt.errorbar(avg_reset_parameters, random_reset_nfs_mia_avg, yerr=random_reset_nfs_mia_std, label='Random Reset NFS_MIA', marker='o', linestyle='None')
    plt.title("Reset NFS_MIA vs Random Reset NFS_MIA")
    plt.xlabel("Avg reset parameters (%)")
    plt.ylabel("NFS_MIA")
    plt.legend()
    plt.grid()
    plt.show()

    plt.errorbar(avg_reset_parameters, retrained_nfs_mia_avg, yerr=retrained_nfs_mia_std, label='Retrained NFS_MIA', marker='o', linestyle='None')
    plt.errorbar(avg_reset_parameters, random_retrained_nfs_mia_avg, yerr=random_retrained_nfs_mia_std, label='Random Retrained NFS_MIA', marker='o', linestyle='None')
    plt.title("Retrained NFS_MIA vs Random Retrained NFS_MIA")
    plt.xlabel("Avg reset parameters (%)")
    plt.ylabel("NFS_MIA")
    plt.legend()
    plt.grid()
    plt.show()
# Out:
# 0.4983000000000001
# 0.6442375000000001
# 0.4983000000000001
# 0.6442375000000001
# 0.4983000000000001
# 0.6442375000000001
# 0.4983000000000001
# 0.6442375000000001

# %%
def find_best(nfs, nta):
    distances = [np.sqrt((nfs[i]-1)**2 + (nta[i]-1)**2) for i in range(len(nfs))]
    best_index = np.argmin(distances)
    return best_index

# %%
plots_folder = "plots"
if not os.path.exists(plots_folder):
    os.makedirs(plots_folder)

dataset_name = init_params['dataset_name']
distribution_type = init_params['distribution_type']

save_path_pref = os.path.join(plots_folder, f"{dataset_name}_{distribution_type}")

# %%
if distribution_type == "random" or distribution_type == "dirichlet":
    plt.plot(reset_nfs_mia_avg, reset_nta_avg, label='Reset', marker='')
    plt.plot(random_reset_nfs_mia_avg, random_reset_nta_avg, label='Random Reset', marker='')

    xlim = plt.xlim()
    ylim = plt.ylim()
    plt.scatter([1], [1], label='Retrain from scratch', color='red', marker='x', s=100)
    plt.hlines(1, xlim[0], xlim[1], colors='red', linestyles=(0, (5, 10)))
    plt.vlines(1, ylim[0], ylim[1], colors='red', linestyles=(0, (5, 10)))
    plt.xlim(xlim)
    plt.ylim(ylim)

    # plt.xlim(left=-0.2)
    # plt.ylim(bottom=0)

    plt.xlabel('NFS MIA')
    plt.ylabel("NTA")

    best_reset_idx = find_best(reset_nfs_mia_avg, reset_nta_avg)
    print(f"Best reset idx: {best_reset_idx}, unlearning percentage: {unlearning_percentages[best_reset_idx]}, reset parameters percentage: {avg_reset_parameters[best_reset_idx]}")
    print(f"NFS_MIA: {reset_nfs_mia_avg[best_reset_idx]}, NTA: {reset_nta_avg[best_reset_idx]}")

    best_random_reset_idx = find_best(random_reset_nfs_mia_avg, random_reset_nta_avg)
    print(f"Best random reset idx: {best_random_reset_idx}, unlearning percentage: {unlearning_percentages[best_random_reset_idx]}, reset parameters percentage: {avg_reset_parameters[best_random_reset_idx]}")
    print(f"NFS_MIA: {random_reset_nfs_mia_avg[best_random_reset_idx]}, NTA: {random_reset_nta_avg[best_random_reset_idx]}")

    plt.scatter(reset_nfs_mia_avg[best_reset_idx], reset_nta_avg[best_reset_idx], label='Best Reset', color='magenta', marker='x', s=100, zorder=5)

    plt.legend()
    plt.grid()

    plt.savefig(save_path_pref + "_NFS_MIA_vs_NTA_reset.png")

    plt.show()


    # plt.plot(retrained_nfs_mia_avg, retrained_nta_avg, label='Retrained', marker='')
    # plt.plot(random_retrained_nfs_mia_avg, random_retrained_nta_avg, label='Random Retrained', marker='')

    # xlim = plt.xlim()
    # ylim = plt.ylim()
    # plt.scatter([1], [1], label='Retrain from scratch', color='red', marker='x', s=100)
    # plt.hlines(1, xlim[0], xlim[1], colors='red', linestyles=(0, (5, 10)))
    # plt.vlines(1, ylim[0], ylim[1], colors='red', linestyles=(0, (5, 10)))
    # plt.xlim(xlim)
    # plt.ylim(ylim)

    # plt.xlabel("NFS MIA")
    # plt.ylabel("NTA")
    # plt.legend()
    # plt.grid()
    # plt.show()
# Out:
# Best reset idx: 7, unlearning percentage: 40, reset parameters percentage: 6.201981336909194
# NFS_MIA: 0.6409516976890349, NTA: 0.5818414940651544
# Best random reset idx: 9, unlearning percentage: 50, reset parameters percentage: 8.776964510221308
# NFS_MIA: 0.6179083491336553, NTA: 0.582511456968496

# %%
if distribution_type == "preferential_class" or distribution_type == "dirichlet":
    plt.clf()
    plt.plot(reset_nfs_avg, reset_nta_avg, label='Reset', marker='')
    plt.plot(random_reset_nfs_avg, random_reset_nta_avg, label='Random Reset', marker='')

    plt.xlabel("NFS")
    plt.ylabel("NTA")

    # plt.ylim(top=1.1)
    # plt.xlim(right=1.5)

    xlim = plt.xlim()
    ylim = plt.ylim()
    plt.scatter([1], [1], label='Retrain from scratch', color='red', marker='x', s=100)
    plt.hlines(1, xlim[0], xlim[1], colors='red', linestyles=(0, (5, 10)))
    plt.vlines(1, ylim[0], ylim[1], colors='red', linestyles=(0, (5, 10)))
    plt.xlim(xlim)
    plt.ylim(ylim)

    best_reset_idx = find_best(reset_nfs_avg, reset_nta_avg)
    print(f"Best reset idx: {best_reset_idx}, unlearning percentage: {unlearning_percentages[best_reset_idx]}, reset parameters percentage: {avg_reset_parameters[best_reset_idx]}")
    print(f"NFS_MIA: {reset_nfs_avg[best_reset_idx]}, NTA: {reset_nta_avg[best_reset_idx]}")

    best_random_reset_idx = find_best(random_reset_nfs_avg, random_reset_nta_avg)
    print(f"Best random reset idx: {best_random_reset_idx}, unlearning percentage: {unlearning_percentages[best_random_reset_idx]}, reset parameters percentage: {avg_reset_parameters[best_random_reset_idx]}")
    print(f"NFS_MIA: {random_reset_nfs_avg[best_random_reset_idx]}, NTA: {random_reset_nta_avg[best_random_reset_idx]}")

    plt.scatter(reset_nfs_avg[best_reset_idx], reset_nta_avg[best_reset_idx], label='Best Reset', color='magenta', marker='x', s=100, zorder=5)

    plt.legend()
    plt.grid()

    plt.savefig(save_path_pref + "_NFS_vs_NTA_reset.png")
    plt.show()


    # plt.plot(retrained_nfs_mia_avg, retrained_nta_avg, label='Retrained', marker='')
    # plt.plot(random_retrained_nfs_mia_avg, random_retrained_nta_avg, label='Random Retrained', marker='')

    # plt.plot(retrained_nfs_avg, retrained_nta_avg, label='Retrained', marker='')
    # plt.plot(random_retrained_nfs_avg, random_retrained_nta_avg, label='Random Retrained', marker='')
    # plt.xlabel("NFS")
    # plt.ylabel("NTA")

    # xlim = plt.xlim()
    # ylim = plt.ylim()
    # plt.scatter([0], [1], label='Retrain from scratch', color='red', marker='x', s=100)
    # plt.hlines(1, xlim[0], xlim[1], colors='red', linestyles=(0, (5, 10)))
    # plt.vlines(0, ylim[0], ylim[1], colors='red', linestyles=(0, (5, 10)))
    # plt.xlim(xlim)
    # plt.ylim(ylim)

    # plt.legend()
    # plt.grid()
    # plt.show()

# %%
idx = best_reset_idx

latex_dist : dict = {
    "random": "Random",
    "dirichlet": "Dirichlet",
    "preferential_class": "Preferential"
}

latex_datasets : dict = {
    "cifar10": "CIFAR-10",
    "FashionMNIST": "FMNIST",
    "mnist": "MNIST"
}

prefix = f"{latex_datasets[dataset_name]} & {latex_dist[distribution_type]} &"

# %%
print("Removal")
print(f"{prefix} ${unlearning_percentages[idx]}$ & ${avg_reset_parameters[idx]:.2f}$ \\\\")
# Out:
# Removal
# CIFAR-10 & Random & $40$ & $6.20$ \\

# %%
print("NTA")
original_test_accuracies = [res['trained_test_accuracy']*100 for res in subtest_results[idx]] # [idx of repeated test]
benchmark_test_accuracies = [res['benchmark_test_accuracy']*100 for res in subtest_results[idx]] # [idx of repeated test]
reset_test_accuracies = [res['reset_test_accuracy']*100 for res in subtest_results[idx]] # [idx of repeated test]

plt.boxplot([original_test_accuracies, benchmark_test_accuracies, reset_test_accuracies], tick_labels=['Original Target', 'Benchmark Target', 'Reset Target'])

print(f"{prefix} ${np.mean(original_test_accuracies):.2f} \\pm {np.std(original_test_accuracies):.2f}$ & ${np.mean(benchmark_test_accuracies):.2f} \\pm {np.std(benchmark_test_accuracies):.2f}$ & ${np.mean(reset_test_accuracies):.2f} \\pm {np.std(reset_test_accuracies):.2f}$ & ${reset_nta_avg[idx]:.2f} \\pm {reset_nta_std[idx]:.2f}$ \\\\")
# Out:
# NTA
# CIFAR-10 & Random & $79.71 \pm 0.49$ & $77.82 \pm 0.75$ & $45.25 \pm 16.73$ & $0.58 \pm 0.22$ \\

# %%
print("NFS")
original_target_accuracies = [res['trained_target_accuracy']*100 for res in subtest_results[idx]] # [idx of repeated test]
benchmark_target_accuracies = [res['benchmark_target_accuracy']*100 for res in subtest_results[idx]] # [idx of repeated test]
reset_target_accuracies = [res['reset_target_accuracy']*100 for res in subtest_results[idx]] # [idx of repeated test]

plt.boxplot([original_target_accuracies, benchmark_target_accuracies, reset_target_accuracies], tick_labels=['Original Target', 'Benchmark Target', 'Reset Target'])

print(f"{prefix} ${np.mean(original_target_accuracies):.2f} \\pm {np.std(original_target_accuracies):.2f}$ & ${np.mean(benchmark_target_accuracies):.2f} \\pm {np.std(benchmark_target_accuracies):.2f}$ & ${np.mean(reset_target_accuracies):.2f} \\pm {np.std(reset_target_accuracies):.2f}$ & ${reset_nfs_avg[idx]:.2f} \\pm {reset_nfs_std[idx]:.2f}$ \\\\")
# Out:
# NFS
# CIFAR-10 & Random & $99.97 \pm 0.03$ & $77.96 \pm 0.71$ & $53.98 \pm 22.02$ & $2.09 \pm 1.01$ \\

# %%
print("NFS_MIA")
original_mia_accuracies = [res['trained_mia_nn']['accuracy']*100 for res in subtest_results[idx]] # [idx of repeated test]
benchmark_mia_accuracies = [res['benchmark_mia_nn']['accuracy']*100 for res in subtest_results[idx]] # [idx of repeated test]
reset_mia_accuracies = [res['reset_mia_nn']['accuracy']*100 for res in subtest_results[idx]] # [idx of repeated test]

plt.boxplot([original_mia_accuracies, benchmark_mia_accuracies, reset_mia_accuracies], tick_labels=['Original MIA', 'Benchmark MIA', 'Reset MIA'])

print(f"{prefix} ${np.mean(original_mia_accuracies):.2f} \\pm {np.std(original_mia_accuracies):.2f}$ & ${np.mean(benchmark_mia_accuracies):.2f} \\pm {np.std(benchmark_mia_accuracies):.2f}$ & ${np.mean(reset_mia_accuracies):.2f} \\pm {np.std(reset_mia_accuracies):.2f}$ & ${reset_nfs_mia_avg[idx]:.2f} \\pm {reset_nfs_mia_std[idx]:.2f}$ \\\\")
# Out:
# NFS_MIA
# CIFAR-10 & Random & $64.42 \pm 0.45$ & $49.83 \pm 0.49$ & $55.04 \pm 3.40$ & $0.64 \pm 0.24$ \\

# %%
from datetime import datetime
start_retrain_str = "15:28:36,006"
stop_retrain_str = "15:41:34,678"
start_reset_str = "15:41:34,678"
stop_reset_str = "15:45:24,672"
start_retrain = datetime.strptime(start_retrain_str, "%H:%M:%S,%f")
stop_retrain = datetime.strptime(stop_retrain_str, "%H:%M:%S,%f")
start_reset = datetime.strptime(start_reset_str, "%H:%M:%S,%f")
stop_reset = datetime.strptime(stop_reset_str, "%H:%M:%S,%f")
retrain_time = (stop_retrain - start_retrain).total_seconds()
reset_time = (stop_reset - start_reset).total_seconds()
print(f"${int(retrain_time)}$ & ${int(reset_time)}$ & ${(reset_time/retrain_time):.2f}$\\\\")
# Out:
# $778$ & $229$ & $0.30$\\
